# %%
df = spark.read.table('prem_catalog.bronze.regions')
df = df.drop('_rescued_data')
df.display()
df.write.format('delta').save('abfss://silver@databricksetestg.dfs.core.windows.net/regions')

# %%
# %sql
CREATE TABLE IF NOT EXISTS prem_catalog.silver.regions_silver
USING DELTA
LOCATION 'abfss://silver@databricksetestg.dfs.core.windows.net/regions'
